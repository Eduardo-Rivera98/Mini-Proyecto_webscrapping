# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time
import pandas as pd
from selenium.webdriver.support.ui import Select
from webdriver_manager.chrome import ChromeDriverManager

# %%
# !ls
# Out:
# README.md  Untitled.ipynb  chromedriver.exe

# %%
driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver)
driver.get("https://github.com/Ironhack-Data-Madrid-Octubre-2021/apuntes_clase")
# Out:
# <ipython-input-10-560c78aac5aa>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver)

# %%
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)

opciones.headless=False   

opciones.add_argument('--start-maximized')         

opciones.add_argument('user-data-dir=selenium')    

opciones.add_argument('drive/adblock.crx') 
opciones.add_argument('--incognito')

# %%
driver = "./chromedriver.exe"
driver = webdriver.Chrome(driver)
driver.get('https://es.investing.com/equities/tesla-motors-historical-data')
# Out:
# <ipython-input-38-228f05c91e74>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(driver)

# %%
info= driver.find_element_by_css_selector('#curr_table' )
# Out:
# <ipython-input-78-ad198a75761a>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   info= driver.find_element_by_css_selector('#curr_table' )

# %%
c=info.text.split('\n')

# %%
Lista=[]
for i in range(len(c)):
    Lista.append(c[i].split(' '))

# %%
Lista
# Out:
# [['Fecha', 'Último', 'Apertura', 'Máximo', 'Mínimo', 'Vol.', '%', 'var.'],
#  ['06.12.2021', '990,08', '999,03', '1.002,25', '951,01', '11,14M', '-2,45%'],
#  ['03.12.2021',
#   '1.014,97',
#   '1.084,79',
#   '1.090,58',
#   '1.000,21',
#   '30,77M',
#   '-6,42%'],
#  ['02.12.2021',
#   '1.084,60',
#   '1.099,06',
#   '1.113,00',
#   '1.056,65',
#   '24,21M',
#   '-0,95%'],
#  ['01.12.2021',
#   '1.095,00',
#   '1.160,69',
#   '1.172,84',
#   '1.090,76',
#   '22,58M',
#   '-4,35%'],
#  ['30.11.2021',
#   '1.144,76',
#   '1.144,37',
#   '1.168,00',
#   '1.118,00',
#   '26,51M',
#   '0,68%'],
#  ['29.11.2021',
#   '1.136,99',
#   '1.100,99',
#   '1.142,67',
#   '1.100,19',
#   '19,19M',
#   '5,09%'],
#  ['26.11.2021',
#   '1.081,92',
#   '1.099,47',
#   '1.108,78',
#   '1.081,00',
#   '11,67M',
#   '-3,05%'],
#  ['24.11.2021',
#   '1.116,00',
#   '1.080,39',
#   '1.132,77',
#   '1.062,00',
#   '22,56M',
#   '0,63%'],
#  ['23.11.2021',
#   '1.109,03',
#   '1.167,51',
#   '1.180,50',
# ...

# %%
df=pd.DataFrame(Lista, columns=Lista[0])
df.drop([0], axis=0, inplace=True)
df.drop(['var.'], axis=1, inplace=True)

# %%
df
# Out:
#          Fecha    Último  Apertura    Máximo    Mínimo    Vol.        %
# 1   06.12.2021    990,08    999,03  1.002,25    951,01  11,14M   -2,45%
# 2   03.12.2021  1.014,97  1.084,79  1.090,58  1.000,21  30,77M   -6,42%
# 3   02.12.2021  1.084,60  1.099,06  1.113,00  1.056,65  24,21M   -0,95%
# 4   01.12.2021  1.095,00  1.160,69  1.172,84  1.090,76  22,58M   -4,35%
# 5   30.11.2021  1.144,76  1.144,37  1.168,00  1.118,00  26,51M    0,68%
# 6   29.11.2021  1.136,99  1.100,99  1.142,67  1.100,19  19,19M    5,09%
# 7   26.11.2021  1.081,92  1.099,47  1.108,78  1.081,00  11,67M   -3,05%
# 8   24.11.2021  1.116,00  1.080,39  1.132,77  1.062,00  22,56M    0,63%
# 9   23.11.2021  1.109,03  1.167,51  1.180,50  1.062,70  35,99M   -4,14%
# 10  22.11.2021  1.156,87  1.162,33  1.201,95  1.132,43  32,38M    1,74%
# 11  19.11.2021  1.137,06  1.098,87  1.138,72  1.092,70  21,64M    3,71%
# 12  18.11.2021  1.096,38  1.106,55  1.112,00  1.075,02  20,90M    0,68%
# ...
